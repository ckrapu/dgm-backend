# %%
import numpy as np

data_path = '../../data/mnist.npy'
mnist = np.load(data_path)
u = np.random.uniform(size=mnist.shape)
binarized = mnist > u

# %%
import matplotlib.pyplot as plt
import utils
plt.figure(figsize=(10,10))
plt.imshow(utils.flatten_image_batch(binarized[0:100,:,:,0],4,4))

# %%
np.save('../data/datasets/training/mnist_binarized.npy',binarized)

# %%
binarized.shape
# Out:
# (60000, 28, 28, 1)
